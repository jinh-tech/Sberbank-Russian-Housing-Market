# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer,StandardScaler
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing

# %%
x_train = pd.read_csv('../data/pre_x_train.csv')
del x_train['id']
del x_train['timestamp']
x_train_id = pd.read_csv('../data/pre_x_train.csv',usecols=['id'])
x_train_time = pd.read_csv('../data/pre_x_train.csv',usecols=['timestamp'])
y_train = pd.read_csv('../data/pre_y_train.csv')

x_test = pd.read_csv('../data/pre_x_test.csv')
del x_test['id']
del x_test['timestamp']
x_test_id = pd.read_csv('../data/pre_x_test.csv',usecols=['id'])
x_test_time = pd.read_csv('../data/pre_x_test.csv',usecols=['timestamp'])

macro = pd.read_csv('../data/pre_macro.csv')

# %%
for f in x_train.columns:
    if x_train[f].dtype==object:
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(x_test[f].values)+list(x_train[f].values)) 
        x_train[f] = lbl.transform(list(x_train[f].values))
        x_test[f] = lbl.transform(list(x_test[f].values))

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.3, random_state=4141)

# %%
params = {}
params['objective'] = 'reg:linear'
params['eval_metric'] = 'rmse'
params['eta'] = 0.02
params['max_depth'] = 6

# %%
d_train = xgb.DMatrix(x_train,y_train)
d_valid = xgb.DMatrix(x_valid,y_valid)
watchlist = [(d_train, 'train'), (d_valid, 'valid')]
bst = xgb.train(params, d_train, 1000, watchlist, early_stopping_rounds=50, verbose_eval=10)
# Out:
# [0]	train-rmse:14.8174	valid-rmse:14.8247
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [10]	train-rmse:12.1113	valid-rmse:12.1182
# [20]	train-rmse:9.9009	valid-rmse:9.90756
# [30]	train-rmse:8.09575	valid-rmse:8.10224
# [40]	train-rmse:6.62187	valid-rmse:6.62817
# [50]	train-rmse:5.4189	valid-rmse:5.42507
# [60]	train-rmse:4.43751	valid-rmse:4.44358
# [70]	train-rmse:3.63746	valid-rmse:3.64343
# [80]	train-rmse:2.98583	valid-rmse:2.99197
# [90]	train-rmse:2.45583	valid-rmse:2.46221
# [100]	train-rmse:2.02565	valid-rmse:2.03234
# [110]	train-rmse:1.67758	valid-rmse:1.68471
# [120]	train-rmse:1.39709	valid-rmse:1.40464
# [130]	train-rmse:1.17243	valid-rmse:1.18093
# [140]	train-rmse:0.993977	valid-rmse:1.00315
# [150]	train-rmse:0.853638	valid-rmse:0.863807
# [160]	train-rmse:0.744864	valid-rmse:0.756021
# [170]	train-rmse:0.661877	valid-rmse:0.674142
# [180]	train-rmse:0.599244	valid-rmse:0.612553
# [190]	train-rmse:0.553122	valid-rmse:0.567451
# [200]	train-rmse:0.519325	valid-rmse:0.534762
# [210]	train-rmse:0.494638	valid-rmse:0.511362
# [220]	train-rmse:0.476812	valid-rmse:0.494717
# [230]	train-rmse:0.464231	valid-rmse:0.483187
# [240]	train-rmse:0.454959	valid-rmse:0.474917
# [250]	train-rmse:0.448162	valid-rmse:0.469209
# [260]	train-rmse:0.442977	valid-rmse:0.46512
# [270]	train-rmse:0.438956	valid-rmse:0.462316
# [280]	train-rmse:0.436127	valid-rmse:0.460187
# [290]	train-rmse:0.433767	valid-rmse:0.458685
# [300]	train-rmse:0.431751	valid-rmse:0.457687
# [310]	train-rmse:0.430065	valid-rmse:0.456674
# [320]	train-rmse:0.428419	valid-rmse:0.456049
# [330]	train-rmse:0.42718	valid-rmse:0.455422
# [340]	train-rmse:0.425985	valid-rmse:0.454983
# [350]	train-rmse:0.424734	valid-rmse:0.454547
# [360]	train-rmse:0.423762	valid-rmse:0.454279
# [370]	train-rmse:0.422828	valid-rmse:0.453998
# [380]	train-rmse:0.421802	valid-rmse:0.453774
# [390]	train-rmse:0.420779	valid-rmse:0.453541
# [400]	train-rmse:0.419783	valid-rmse:0.453341
# [410]	train-rmse:0.418705	valid-rmse:0.453158
# [420]	train-rmse:0.417549	valid-rmse:0.453037
# [430]	train-rmse:0.416692	valid-rmse:0.452919
# [440]	train-rmse:0.415514	valid-rmse:0.452827
# [450]	train-rmse:0.414701	valid-rmse:0.452743
# [460]	train-rmse:0.413795	valid-rmse:0.452662
# [470]	train-rmse:0.412844	valid-rmse:0.452648
# [480]	train-rmse:0.411968	valid-rmse:0.452658
# [490]	train-rmse:0.41093	valid-rmse:0.452533
# [500]	train-rmse:0.410155	valid-rmse:0.452538
# [510]	train-rmse:0.409379	valid-rmse:0.45252
# [520]	train-rmse:0.408663	valid-rmse:0.452443
# [530]	train-rmse:0.40782	valid-rmse:0.452356
# [540]	train-rmse:0.407076	valid-rmse:0.452347
# [550]	train-rmse:0.406161	valid-rmse:0.452348
# [560]	train-rmse:0.405167	valid-rmse:0.452352
# [570]	train-rmse:0.404277	valid-rmse:0.452336
# [580]	train-rmse:0.40347	valid-rmse:0.452306
# [590]	train-rmse:0.402829	valid-rmse:0.452297
# [600]	train-rmse:0.402073	valid-rmse:0.452253
# [610]	train-rmse:0.401212	valid-rmse:0.452237
# [620]	train-rmse:0.400407	valid-rmse:0.452209
# [630]	train-rmse:0.399722	valid-rmse:0.452251
# [640]	train-rmse:0.398863	valid-rmse:0.452294
# [650]	train-rmse:0.398122	valid-rmse:0.452281
# Stopping. Best iteration:
# [606]	train-rmse:0.401578	valid-rmse:0.452193

# %%
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(bst, max_num_features=50, height=0.8, ax=ax)
plt.show()

# %%
d_test = xgb.DMatrix(x_test)
y_test = bst.predict(d_test)

# %%
sub = pd.DataFrame()
sub['id'] = np.array(x_test_id['id'].values,np.int32)
sub['price_doc'] = np.exp(y_test)-1.0
sub.to_csv('../output/simple5.csv', index=False)
